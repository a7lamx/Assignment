# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#read data
path = 'D:\\ML assignment\\pop.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])

#show data details
print('data = \n' ,data.head(10) )
print('data.describe = \n',data.describe())
#draw data
data.plot(kind='scatter', x='Population', y='Profit', figsize=(5,5))
# Out:
# data =
#     Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233
# 5      8.3829  11.8860
# 6      7.4764   4.3483
# 7      8.5781  12.0000
# 8      6.4862   6.5987
# 9      5.0546   3.8166
# data.describe =
#         Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000
# <AxesSubplot:xlabel='Population', ylabel='Profit'>

# %%
#**********************EDA***********************
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.tail()
# Out:
#     Population   Profit
# 92      5.8707  7.20290
# 93      5.3054  1.98690
# 94      8.2934  0.14454
# 95     13.3940  9.05510
# 96      5.4369  0.61705

# %%
data.shape
# Out:
# (97, 2)

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.columns
# Out:
# Index(['Population', 'Profit'], dtype='object')

# %%
data.nunique()
# Out:
# Population    97
# Profit        97
# dtype: int64

# %%
data['Population'].unique()
# Out:
# array([ 6.1101,  5.5277,  8.5186,  7.0032,  5.8598,  8.3829,  7.4764,
#         8.5781,  6.4862,  5.0546,  5.7107, 14.164 ,  5.734 ,  8.4084,
#         5.6407,  5.3794,  6.3654,  5.1301,  6.4296,  7.0708,  6.1891,
#        20.27  ,  5.4901,  6.3261,  5.5649, 18.945 , 12.828 , 10.957 ,
#        13.176 , 22.203 ,  5.2524,  6.5894,  9.2482,  5.8918,  8.2111,
#         7.9334,  8.0959,  5.6063, 12.836 ,  6.3534,  5.4069,  6.8825,
#        11.708 ,  5.7737,  7.8247,  7.0931,  5.0702,  5.8014, 11.7   ,
#         5.5416,  7.5402,  5.3077,  7.4239,  7.6031,  6.3328,  6.3589,
#         6.2742,  5.6397,  9.3102,  9.4536,  8.8254,  5.1793, 21.279 ,
#        14.908 , 18.959 ,  7.2182,  8.2951, 10.236 ,  5.4994, 20.341 ,
#        10.136 ,  7.3345,  6.0062,  7.2259,  5.0269,  6.5479,  7.5386,
#         5.0365, 10.274 ,  5.1077,  5.7292,  5.1884,  6.3557,  9.7687,
#         6.5159,  8.5172,  9.1802,  6.002 ,  5.5204,  5.0594,  5.7077,
#         7.6366,  5.8707,  5.3054,  8.2934, 13.394 ,  5.4369])

# %%
#Cleaning data
data.isnull().sum()
# Out:
# Population    0
# Profit        0
# dtype: int64

# %%
#since there are only 2 columns I don't neet to drop any 
plt.hist(data.values)
plt.show()

# %%
#relashonship analysis 
import seaborn as sns 
corelation = data.corr()
sns.heatmap(corelation, xticklabels = corelation.columns , yticklabels = corelation.columns , annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Population',y='Profit',hue='Population', data=data)

# %%
sns.distplot(data['Profit' ], bins = 20)
# Out:
# C:\Users\anwaa\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.catplot(x='Profit',kind='box',data=data)
#fq=data['profit'].quantile(.35)
#thq=data['profit'].quantile(.75)
#IQR=thq-fq
#newboundry = thq+ 3*IQR
#data.drop(data[data['profit']>newboundry].index,axis=0,inplace=True)
#sns.catplot(x='profit',kind='box',data=data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  97 non-null     float64
#  1   Profit      97 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
#************************************ MY linear regression MODEL*************************************************
import pandas as pd
path = 'D:\\ML assignment\\pop.txt'
df = pd.read_csv(path, header=None, names=['Population', 'Profit'])
df.head()
x = df.Population
y = df.Profit
import matplotlib.pyplot as plt
plt.scatter(x,y)
#caculate the slope of m of the regression line 
#SSXX
xmean =x.mean()
df['diffx'] = xmean - x 
df['diffx_squared'] =df.diffx**2
SSxx =df.diffx_squared.sum()
#*****************************************************
#SSxy
ymean =y.mean()
df['diffy'] = ymean - y
SSxy =(df.diffx * df.diffy).sum()

#******************************************************
#SLOPE m = SSXX/SSxy
slope = SSxx/SSxy
slope
#*****************************************************
#Calculate the interciept b for the regression line b='y - m * `x
b = ymean - slope * xmean
b
#************************************************************
#predict the values with the model
def predict(value):
    predict =slope * value + b
    return predict
#**************************************************************
predict(7.0032)

import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,slope * x + b , 'r')

# %%
from sklearn.metrics import r2_score
r2_score(x,slope * x + b)
# Out:
# 0.6104668334917408

# %%
#explained_variance_score
from sklearn.metrics import explained_variance_score
explained_variance_score(x, slope * x + b)
# Out:
# 0.973820542854689

# %%
#mean_squared_error(MSE)
#from sklearn.metrics import mean_squared_error
#mean_squared_error(x,slope * x + b)

# %%
#Root_mean_squared_error(RMSE)
#from sklearn.metrics import mean_squared_error  
#import math
#MSE = mean_squared_error(x,slope * x + b)
#rmse = math.sqrt(MSE)

#print(rmse)

# %%
#median_absolute_error(MAE)
#from sklearn.metrics import median_absolute_error
#median_absolute_error(x,slope * x + b)

# %%
#mean_absolute_error(MAE) 
#from sklearn.metrics import mean_absolute_error
#mean_absolute_error(x,slope * x + b)

# %%
#Check the model via the residual plot
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('Population  ~ Profit', data = df).fit()
print (model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Population   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     223.8
# Date:                Sun, 10 Oct 2021   Prob (F-statistic):           1.02e-26
# Time:                        17:30:24   Log-Likelihood:                -209.67
# No. Observations:                  97   AIC:                             423.3
# Df Residuals:                      95   BIC:                             428.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.7238      0.315     14.995      0.000       4.098       5.349
# ...

# %%
#***************************************Regularized linear regression ***************************************
from sklearn.linear_model import Ridge
import numpy as np
n_samples, n_features = 10, 5
rng = np.random.RandomState(0)
y = rng.randn(n_samples)
x = rng.randn(n_samples, n_features)
clf = Ridge(alpha=0.01)
clf.fit(x,y)
Ridge()
# Out:
# Ridge()

# %%
#***************************************************residual plot*************************************************
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(model,'Profit',fig=fig)

# %%
uhat=model.resid
plt.plot(uhat)
plt.xlabel('data')
plt.ylabel('residual')
plt.grid(True)
plt.show()

# %%
yhat=model.fittedvalues
plt.plot(yhat)

# %%
plt.plot(df.Profit,label='actual profit')
plt.plot(yhat,label='predicted profit')
plt.xlabel('data')
plt.ylabel('index')
plt.grid(True)
legend=plt.legend()
plt.show()

# %%
#**************************************SKLEARN LINEAR REGRESSION MODEL*****************************************
import numpy as np
import pandas as pd


#read data
path = 'D:\\ML assignment\\pop.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])
data.columns = ['Population', 'Profit']
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
x=data.drop(['Profit'],axis=1).values

y=data['Profit'].values
#print (x)
#print(y)
from sklearn.model_selection import train_test_split
import numpy as np
#x,y = np.arange(10).reshape((5, 2)), range(5)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=0)
from sklearn.linear_model import LinearRegression
ln = LinearRegression()
ln.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = ln.predict(x_test)
print(y_pred)
ln.predict([[7.0032]])
# Out:
# [11.51443267  3.94813261  6.34876459  3.75993706  2.72965634  2.35686134
#   3.76772859  8.45295862  3.72865105  6.08085564  5.2513568   2.20222933
#   4.92938658  6.2166681   6.42008711  2.433578    2.71850845  2.80817105
#   3.20002534  3.91253128  3.05845914 21.64462736  4.53225802  7.14182302
#   4.64002095 10.16230161  5.09948179  2.65473773  3.00511709  3.98649093]
# array([4.53225802])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.592517025321679

# %%
#explained_variance_score
from sklearn.metrics import explained_variance_score
explained_variance_score(y_test,y_pred)
# Out:
# 0.5954792502130357

# %%
#mean_squared_error(MSE)
#from sklearn.metrics import mean_squared_error
#mean_squared_error(y_test,y_pred)

# %%
#Root_mean_squared_error(RMSE)
#from sklearn.metrics import mean_squared_error  
#import math
#MSE = mean_squared_error(y_test,y_pred)
#rmse = math.sqrt(MSE)

#print(rmse)

# %%
#mean_absolute_error(MAE) 
#from sklearn.metrics import mean_absolute_error
#mean_absolute_error(y_test,y_pred)

# %%
#median_absolute_error(MAE)
#from sklearn.metrics import median_absolute_error
#median_absolute_error(y_test, y_pred)

# %%
#from sklearn.metrics import max_error
#max_error(y_test, y_pred)

# %%
import sklearn.metrics as metrics
#from sklearn.metrics import r2_score
#r2=r2_score(y_test,y_pred)
#r2_sk = metrics.r2_score(y_test, y_pred)
N=y_test.shape[0]
p=3
x = (1-r2)
y = (N-1) / (N-p-1)
adj_rsquared = (1 - (x * y))
print("Adjusted-R2 : " , adj_rsquared)
# Out:
# Adjusted-R2 :  0.545499759012642

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.scatter(y_test,y_pred)

plt.xlabel('Actual')
plt.xlabel('predicted')
plt.title('Actual vs. predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs. predicted')

# %%
prd_y_df = pd.DataFrame({'actual value':y_test,'predicted value':y_pred,'diffrence':y_test-y_pred})
prd_y_df[0:20]
# Out:
#     actual value  predicted value  diffrence
# 0       13.50100        11.514433   1.986567
# 1        5.34360         3.948133   1.395467
# 2       13.66200         6.348765   7.313235
# 3       -1.42110         3.759937  -5.181037
# 4        1.01730         2.729656  -1.712356
# 5        0.20421         2.356861  -2.152651
# 6        5.30480         3.767729   1.537071
# 7        6.75260         8.452959  -1.700359
# 8        1.42330         3.728651  -2.305351
# 9        5.74420         6.080856  -0.336656
# 10       4.99810         5.251357  -0.253257
# 11       2.82140         2.202229   0.619171
# 12       4.02590         4.929387  -0.903487
# 13       7.22580         6.216668   1.009132
# 14      12.00000         6.420087   5.579913
# 15      -1.22000         2.433578  -3.653578
# 16       4.26300         2.718508   1.544492
# 17       3.08250         2.808171   0.274329
# 18       1.84950         3.200025  -1.350525
# 19       6.59870         3.912531   2.686169

# %%
linreg = LinearRegression()
x=x.reshape(-1,1)
linreg.fit(x,y)
y_pred =linreg.predict(x)
plt.scatter(x,y)
plt.plot(x,y_pred,'r')
plt.show()

# %%
import numpy as np 
from statistics import mean 
import matplotlib.pyplot as plt
        
x_list = data['Population'].tolist()
y_list = data[ 'Profit'].tolist()

        
xs = np.array(x_list, dtype=np.float64)
ys = np.array(y_list, dtype=np.float64)

def best_fit_slope_and_intercept(x,y): 
    slope = (((mean(xs) * mean(ys)) - mean(xs*ys)) / ((mean(xs) * mean(xs)) - mean(xs*xs)))
    intr = mean(ys) - slope * mean(xs)                      
    return slope, intr
                                                  
slope,intr = best_fit_slope_and_intercept(xs,ys) 
print (slope , intr)
# Out:
# 1.1930336441895946 -3.8957808783118635

# %%
from sklearn.linear_model import Ridge
import numpy as np
n_samples, n_features = 10, 5
rng = np.random.RandomState(0)
y = rng.randn(n_samples)
x = rng.randn(n_samples, n_features)
clf = Ridge(alpha=0.01)
clf.fit(x_train,y_train)
Ridge()
# Out:
# Ridge()

# %%
clf.predict([[7.0032]])
# Out:
# array([4.5322595])

# %%
#Check the model via the residual plot
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('Population  ~ Profit', data = data).fit()
print (model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Population   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     223.8
# Date:                Sun, 10 Oct 2021   Prob (F-statistic):           1.02e-26
# Time:                        17:38:50   Log-Likelihood:                -209.67
# No. Observations:                  97   AIC:                             423.3
# Df Residuals:                      95   BIC:                             428.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.7238      0.315     14.995      0.000       4.098       5.349
# ...

# %%
uhat=model.resid
plt.plot(uhat)
plt.xlabel('data')
plt.ylabel('residual')
plt.grid(True)
plt.show()

# %%
yhat=model.fittedvalues
plt.plot(yhat)

# %%
plt.plot(data['Profit'].values,label='actual profit')
plt.plot(yhat,label='predicted profit')
plt.xlabel('data')
plt.ylabel('index')
plt.grid(True)
legend=plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(model,'Profit',fig=fig)

# %%
#************************************POLYNOMIAL REGRESSION*************************************************
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
#read data
data = pd.read_csv('D:\\ML assignment\\pop.txt', header=None)
data.columns = ['population', 'profit']
#data needs to be ordered with respect to the predictor
data = data.sort_values(by=['population'])
data.head()
# Out:
#     population  profit
# 74      5.0269 -2.6807
# 77      5.0365  5.7014
# 9       5.0546  3.8166
# 89      5.0594  2.8214
# 46      5.0702  5.1337

# %%
X = data.iloc[:,0].values.reshape(-1,1)
Y = data.iloc[:,1].values.reshape(-1,1)

# %%
 #Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
lin.fit(X, Y)

from sklearn.preprocessing import PolynomialFeatures
  
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(X)
poly.fit(X_poly,Y)
lin2 = LinearRegression()
lin2.fit(X_poly, Y )
# Out:
# LinearRegression()

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, Y, color = 'red')
  
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'black')
plt.title('Polynomial Regression')
plt.xlabel('population')
plt.ylabel('Profit')
  
plt.show()

# %%
from sklearn.model_selection import train_test_split
import numpy as np
#x,y = np.arange(10).reshape((5, 2)), range(5)
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.3,random_state=0)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
poly = PolynomialFeatures(degree = 4)


X_train = poly.fit_transform(x_train)
X_test = poly.fit_transform(x_test)

model = linear_model.LinearRegression()
model.fit(x_train, y_train)

print(model.score(x_train, y_train))
# Out:
# 0.7009457123766507

# %%
y_pred = model.predict(x_test)
#print(y_pred)
model.predict([[7.0032]])
# Out:
# array([[4.41781627]])

# %%
#************************************COST FUNCTION / GRADIENT DESCENT CODE *****************************************
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#read data
path = 'D:\\ML assignment\\pop.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])

#show data details
print('data = \n' ,data.head(10) )
print('data.describe = \n',data.describe())
#draw data
data.plot(kind='scatter', x='Population', y='Profit', figsize=(5,5))
# Out:
# data =
#     Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233
# 5      8.3829  11.8860
# 6      7.4764   4.3483
# 7      8.5781  12.0000
# 8      6.4862   6.5987
# 9      5.0546   3.8166
# data.describe =
#         Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000
# <AxesSubplot:xlabel='Population', ylabel='Profit'>

# %%
# adding a new column called ones before the data(X0)
#data.insert(0, 'Ones', 1)
print('new data = \n' ,data.head(10) )


# separate X (training data) from y (target variable)
cols = data.shape[1]
X = data.iloc[:,0:cols-1]
y = data.iloc[:,cols-1:cols]
print('X data = \n' ,X.head(5) )
print('y data = \n' ,y.head(5) )

#****************************************
X = np.matrix(X.values)
y = np.matrix(y.values)
theta = np.matrix(np.array([0,0])) 
#***********************************
# Out:
# new data =
#     Ones  Population   Profit
# 0     1      6.1101  17.5920
# 1     1      5.5277   9.1302
# 2     1      8.5186  13.6620
# 3     1      7.0032  11.8540
# 4     1      5.8598   6.8233
# 5     1      8.3829  11.8860
# 6     1      7.4764   4.3483
# 7     1      8.5781  12.0000
# 8     1      6.4862   6.5987
# 9     1      5.0546   3.8166
# X data =
#     Ones  Population
# 0     1      6.1101
# 1     1      5.5277
# 2     1      8.5186
# 3     1      7.0032
# 4     1      5.8598
# y data =
#      Profit
# 0  17.5920
# 1   9.1302
# 2  13.6620
# 3  11.8540
# 4   6.8233

# %%
# cost function  {J(01,02)=1/2m segma i=1 to m(h0(Xi)-y(i))**2}  where m is (numbwe of sampels)=len(x)
def computeCost(X, y, theta):
    C= np.power(((X * theta.T) - y), 2)

    return np.sum(C) / (2 * len(X))

print('computeCost(X, y, theta) = ' , computeCost(X, y, theta))
# Out:
# computeCost(X, y, theta) =  32.072733877455676

# %%
# GD function 0.= 0.- alpha*1/m segma i=1 to m (h0(Xi)-yi)
            # 01= 01- alpha*1/m segma i=1 to m ((h0(Xi)-yi)Xi)  {update theta(0.,01)}
    
def gradientDescent(X, y, theta, alpha, iters):
    temp = np.matrix(np.zeros(theta.shape))
    parameters = int(theta.ravel().shape[1])
    cost = np.zeros(iters)
    
    for i in range(iters):
        error = (X * theta.T) - y #cost function
        
        for j in range(parameters): #0(1) , 1(x)
            term = np.multiply(error, X[:,j])
            temp[0,j] = theta[0,j] - ((alpha / len(X)) * np.sum(term))
            
        theta = temp #update theta
        cost[i] = computeCost(X, y, theta) #call another function(cost function)
        
    return theta, cost


# initialize variables for learning rate(ALPHA) and iterations
alpha = 0.01
iters = 1000

# perform gradient descent to "fit" the model parameters
g, cost = gradientDescent(X, y, theta, alpha, iters)

#print('g = ' , g)
#print('cost  = ' , cost[0:50] )
print('computeCost = ' , computeCost(X, y, g))



# get best fit line

x = np.linspace(data.Population.min(), data.Population.max(), 100)
#print('x \n',x)
#print('g \n',g)

f = g[0, 0] + (g[0, 1] * x)  # linear regression equation {h0 (x) = 0.+ 01x}
print('f \n',f)




# draw the line

fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x, f, 'r', label='Prediction')
ax.scatter(data.Population, data.Profit, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('Population')
ax.set_ylabel('Profit')
ax.set_title('Predicted Profit vs. Population Size')


# draw error graph

fig, ax = plt.subplots(figsize=(5,5))
ax.plot(np.arange(iters), cost, 'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')
ax.set_title('Error vs. Training Epoch')
# Out:
# computeCost =  4.515955503078914
# f
#  [ 2.42539308  2.62097407  2.81655506  3.01213605  3.20771704  3.40329803
#   3.59887902  3.79446001  3.990041    4.18562199  4.38120298  4.57678397
#   4.77236495  4.96794594  5.16352693  5.35910792  5.55468891  5.7502699
#   5.94585089  6.14143188  6.33701287  6.53259386  6.72817485  6.92375584
#   7.11933683  7.31491782  7.51049881  7.7060798   7.90166079  8.09724177
#   8.29282276  8.48840375  8.68398474  8.87956573  9.07514672  9.27072771
#   9.4663087   9.66188969  9.85747068 10.05305167 10.24863266 10.44421365
#  10.63979464 10.83537563 11.03095662 11.2265376  11.42211859 11.61769958
#  11.81328057 12.00886156 12.20444255 12.40002354 12.59560453 12.79118552
#  12.98676651 13.1823475  13.37792849 13.57350948 13.76909047 13.96467146
#  14.16025245 14.35583344 14.55141442 14.74699541 14.9425764  15.13815739
#  15.33373838 15.52931937 15.72490036 15.92048135 16.11606234 16.31164333
# ...
